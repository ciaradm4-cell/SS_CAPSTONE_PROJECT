# %%
import pandas as pd
import numpy as np
from subprocess import Popen, PIPE
import re
from scipy import ndimage
import glob
import sys
from pathlib import Path
import PlotAllSky
import SkyMultiMap_vars as ext_vars
from filesplit.split import Split

# %%
datafile = '/Users/ciaradeasymillar/SS_CAPSTONE/Data/ciara/192809/sb197_int_5_duration_100/20260923_192947_sb197_xst.dat'
split = Split(inputfile= datafile, outputdir= '/Users/ciaradeasymillar/SS_CAPSTONE/Data/filesplittest')

split.bysize(size=589824)
